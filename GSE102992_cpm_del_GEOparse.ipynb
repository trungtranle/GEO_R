# %%
import GEOparse

# %%
gse = GEOparse.get_GEO(filepath= 'GSE102992_family.soft.gz')
# Out:
# 10-Dec-2018 23:22:09 INFO GEOparse - Parsing GSE102992_family.soft.gz:
# 10-Dec-2018 23:22:09 DEBUG GEOparse - DATABASE: GeoMiame
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SERIES: GSE102992
# 10-Dec-2018 23:22:09 DEBUG GEOparse - PLATFORM: GPL17021
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752209
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752210
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752211
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752212
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752213
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752214
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752215
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752216
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752217
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752218
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752219
# 10-Dec-2018 23:22:09 DEBUG GEOparse - SAMPLE: GSM2752220
# ...

# %%
gse.gpls['GPL17021'].columns
# Out:
# Empty DataFrame
# Columns: [description]
# Index: []

# %%
gse.phenotype_data[['characteristics_ch1.1.nutritional state','source_name_ch1']]
# Out:
#            characteristics_ch1.1.nutritional state          source_name_ch1
# GSM2752209                                    Fast          arcuate nucleus
# GSM2752210                                    Fast          arcuate nucleus
# GSM2752211                                    Fast          arcuate nucleus
# GSM2752212                                    Fast          arcuate nucleus
# GSM2752213                                     Fed          arcuate nucleus
# GSM2752214                                     Fed          arcuate nucleus
# GSM2752215                                     Fed          arcuate nucleus
# GSM2752216                                     Fed          arcuate nucleus
# GSM2752217                                     Fed          arcuate nucleus
# GSM2752218                                    Fast      dorsomedial nucleus
# GSM2752219                                    Fast      dorsomedial nucleus
# ...

# %%
from pprint import pprint
pprint(vars(gse))
# Out:
# {'_phenotype_data':            channel_count characteristics_ch1.0.strain  \
# GSM2752209             1                      C57/BL6
# GSM2752210             1                      C57/BL6
# GSM2752211             1                      C57/BL6
# GSM2752212             1                      C57/BL6
# GSM2752213             1                      C57/BL6
# GSM2752214             1                      C57/BL6
# GSM2752215             1                      C57/BL6
# GSM2752216             1                      C57/BL6
# GSM2752217             1                      C57/BL6
# GSM2752218             1                      C57/BL6
# GSM2752219             1                      C57/BL6
# GSM2752220             1                      C57/BL6
# GSM2752221             1                      C57/BL6
# GSM2752222             1                      C57/BL6
# GSM2752223             1                      C57/BL6
# GSM2752224             1                      C57/BL6
# ...

# %%
GEOparse.GPL()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-609405470fe9> in <module>()
# ----> 1 GEOparse.GPL()
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'metadata'

# %%
gpl = GEOparse.get_GEO('GPL17021')
# Out:
# 11-Dec-2018 09:16:25 DEBUG utils - Directory ./ already exists. Skipping.
# 11-Dec-2018 09:16:25 INFO GEOparse - Downloading http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL17021&form=text&view=full to ./GPL17021.txt
# 11-Dec-2018 09:16:25 INFO utils - Downloading http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?targ=self&acc=GPL17021&form=text&view=full to ./GPL17021.txt
# Downloading: 3.8MiB / Unknown - 3.6MiB/s
# 11-Dec-2018 09:16:36 INFO GEOparse - Parsing ./GPL17021.txt:
# 11-Dec-2018 09:16:36 DEBUG GEOparse - PLATFORM: GPL17021

# %%
# Out:
# {}
