# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import GEOparse

# %%
gse = GEOparse.parse_GSE('GSE81993_family_af.soft.gz')
# Out:
# 10-Dec-2018 22:50:10 DEBUG GEOparse - DATABASE: GeoMiame
# 10-Dec-2018 22:50:10 DEBUG GEOparse - SERIES: GSE81993
# 10-Dec-2018 22:50:10 DEBUG GEOparse - PLATFORM: GPL11180
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.
# 10-Dec-2018 22:50:13 DEBUG GEOparse - SAMPLE: GSM2179744
# 10-Dec-2018 22:50:13 DEBUG GEOparse - SAMPLE: GSM2179745
# 10-Dec-2018 22:50:13 DEBUG GEOparse - SAMPLE: GSM2179746
# 10-Dec-2018 22:50:13 DEBUG GEOparse - SAMPLE: GSM2179747
# 10-Dec-2018 22:50:14 DEBUG GEOparse - SAMPLE: GSM2179748
# 10-Dec-2018 22:50:14 DEBUG GEOparse - SAMPLE: GSM2179749
# 10-Dec-2018 22:50:14 DEBUG GEOparse - SAMPLE: GSM2179750
# 10-Dec-2018 22:50:14 DEBUG GEOparse - SAMPLE: GSM2179751
# 10-Dec-2018 22:50:15 DEBUG GEOparse - SAMPLE: GSM2179752
# 10-Dec-2018 22:50:15 DEBUG GEOparse - SAMPLE: GSM2179753
# ...

# %%
gse.gpls['GPL11180'].table
# Out:
#                                  ID     GB_ACC             SPOT_ID  \
# 0                     1415670_PM_at   BC024686                 NaN
# 1                     1415671_PM_at  NM_013477                 NaN
# 2                     1415672_PM_at  NM_020585                 NaN
# 3                     1415673_PM_at  NM_133900                 NaN
# 4                   1415674_PM_a_at  NM_021789                 NaN
# 5                     1415675_PM_at   BC008256                 NaN
# 6                   1415676_PM_a_at  NM_011186                 NaN
# 7                     1415677_PM_at  NM_026819                 NaN
# 8                     1415678_PM_at   BC008595                 NaN
# 9                     1415679_PM_at  NM_025498                 NaN
# 10                    1415680_PM_at  NM_008569                 NaN
# 11                    1415681_PM_at  NM_053164                 NaN
# 12                    1415682_PM_at  NM_023045                 NaN
# ...

# %%
control_fast = ['GSM2179744', 'GSM2179745', 'GSM2179746',]
control_fed = ['GSM2179747', 'GSM2179748', 'GSM2179749', 'GSM2179750',]
ko_fast = ['GSM2179751', 'GSM2179752', 'GSM2179753',]
ko_fed = ['GSM2179754', 'GSM2179755', 'GSM2179756', 'GSM2179757',]

# %%
pivoted_control_fast = gse.pivot_samples('VALUE')[control_fast]
pivoted_control_fed = gse.pivot_samples('VALUE')[control_fed]
ko_fast = gse.pivot_samples('VALUE')[ko_fast]
ko_fed = gse.pivot_samples('VALUE')[ko_fed]

# %%
pivoted_control_fast[control_fast]
# Out:
# name                   GSM2179744  GSM2179745  GSM2179746
# ID_REF
# 1415670_PM_at                9.29        9.25        9.30
# 1415671_PM_at               11.42       11.29       11.38
# 1415672_PM_at               10.75       10.81       10.82
# 1415673_PM_at                7.98        7.83        7.99
# 1415674_PM_a_at              9.57        9.65        9.64
# 1415675_PM_at                8.55        8.26        8.55
# 1415676_PM_a_at             10.82       10.74       10.70
# 1415677_PM_at                9.23        9.05        9.26
# 1415678_PM_at               10.61       10.54       10.63
# 1415679_PM_at               10.44       10.44       10.42
# 1415680_PM_at                7.82        7.75        7.81
# 1415681_PM_at                9.87        9.86        9.82
# 1415682_PM_at                8.09        8.15        8.15
# 1415683_PM_at                9.79        9.91        9.90
# 1415684_PM_at                8.22        8.21        8.31
# ...

# %%
plt.boxplot(gse.pivot_samples('VALUE'))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-6b9f761210ad>", line 1, in <module>
#     plt.boxplot(gse.pivot_samples('VALUE'))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py", line 2848, in boxplot
#     zorder=zorder, data=data)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py", line 1855, in inner
#     return func(ax, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 3669, in boxplot
#     manage_xticks=manage_xticks, zorder=zorder)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py", line 4027, in bxp
#     whisker_x, whiskerhi_y, **final_whiskerprops
# ...
